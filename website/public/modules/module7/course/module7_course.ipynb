# %%
# Deep Learning Fundamentals: MNIST Case Study
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Data Collection

# %%
import requests

# URLs of the files
data_features_url = 'https://www.raphaelcousin.com/modules/module7/course/module7_course_features.csv'
data_labels_url = 'https://www.raphaelcousin.com/modules/module7/course/module7_course_labels.csv'

# Function to download a file
def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f'Downloaded {file_name} from {url}')

# Downloading the files
download_file(data_features_url, 'module7_course_features.csv')
download_file(data_labels_url, 'module7_course_labels.csv')
# Out:
# Downloaded module7_course_features.csv from https://www.raphaelcousin.com/modules/module7/course/module7_course_features.csv
# Downloaded module7_course_labels.csv from https://www.raphaelcousin.com/modules/module7/course/module7_course_labels.csv

# %%
X = pd.read_csv('module7_course_features.csv').values
y = pd.read_csv('module7_course_labels.csv').values.ravel()

# %% [markdown]
# ### Data Analysis

# %%
X.shape
# Out:
# (60000, 784)

# %%
y.shape
# Out:
# (60000,)

# %%
def plot_mnist_digits(X, y, num_examples=5, figsize=(15, 3)):
    # Create figure
    fig, axes = plt.subplots(1, num_examples, figsize=figsize)
    
    # Ensure axes is always a numpy array
    if num_examples == 1:
        axes = np.array([axes])
    
    # Plot each example
    for i in range(num_examples):
        # Reshape the flattened image back to 28x28
        img = X[i].reshape(28, 28)
        
        # Plot
        axes[i].imshow(img, cmap='gray')
        axes[i].set_title(f'Label: {y[i]}')
        axes[i].axis('off')
    
    plt.tight_layout()
    return fig

# %%
# Plot some examples
fig = plot_mnist_digits(X, y, num_examples=5)
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
from torch.utils.data import TensorDataset, Dataset, DataLoader, random_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
def preprocess_data(X, y, batch_size=32, train_size=0.7, val_size=0.15, random_state=42):
    # Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Split data into train+val and test
    test_size = 1 - train_size - val_size
    X_trainval, X_test, y_trainval, y_test = train_test_split(
        X_scaled, y, test_size=test_size, 
        random_state=random_state, stratify=y
    )
    
    # Split train+val into train and val
    X_train, X_val, y_train, y_val = train_test_split(
        X_trainval, y_trainval, 
        test_size=val_size/(train_size + val_size),
        random_state=random_state, stratify=y_trainval
    )
    
    # Convert to tensors and create dataloaders
    loaders = {
        'train': DataLoader(
            TensorDataset(torch.FloatTensor(X_train), torch.LongTensor(y_train)),
            batch_size=batch_size, shuffle=True
        ),
        'val': DataLoader(
            TensorDataset(torch.FloatTensor(X_val), torch.LongTensor(y_val)),
            batch_size=batch_size
        ),
        'test': DataLoader(
            TensorDataset(torch.FloatTensor(X_test), torch.LongTensor(y_test)),
            batch_size=batch_size
        )
    }
    
    return loaders['train'], loaders['val'], loaders['test'], scaler

# %%
train_loader, val_loader, test_loader, scaler = preprocess_data(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_loader, val_loader, test_loader, scaler = preprocess_data(X, y)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### Model

# %%
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau

def create_model(device):
    dropout_rate = 0.2
    model = nn.Sequential(
                # First hidden layer
                nn.Linear(784, 512),
                nn.ReLU(),
                nn.BatchNorm1d(512),
                nn.Dropout(dropout_rate),
                
                # Second hidden layer
                nn.Linear(512, 256),
                nn.ReLU(),
                nn.BatchNorm1d(256),
                nn.Dropout(dropout_rate),
                
                # Third hidden layer
                nn.Linear(256, 128),
                nn.ReLU(),
                nn.BatchNorm1d(128),
                nn.Dropout(dropout_rate),
                
                # Output layer
                nn.Linear(128, 10)
            ).to(device)
    
    
    # Define loss function
    criterion = nn.CrossEntropyLoss().to(device)
    
    # Define optimizer (with reasonable defaults)
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=0.01,
        betas=(0.9, 0.999),
        eps=1e-08,
        weight_decay=0.0001
    )

    scheduler = ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.1,
        patience=5,
        verbose=True,
        min_lr=1e-6
    )
    return model, criterion, optimizer, scheduler

# %% [markdown]
# ### Train

# %%
import torch
import torch.nn as nn
import numpy as np
from time import time
from collections import defaultdict

class EarlyStopping:
    def __init__(self, patience=7, min_delta=0, path='checkpoint.pt'):
        self.patience = patience
        self.min_delta = min_delta
        self.path = path
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.val_loss_min = np.inf

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss > self.best_loss + self.min_delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

def train_epoch(model, loader, criterion, optimizer, device, is_training=True):
    """Run one epoch of training or validation."""
    model.train() if is_training else model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    
    context = torch.enable_grad() if is_training else torch.no_grad()
    with context:
        for data, target in loader:
            data, target = data.to(device), target.to(device)
            
            if is_training:
                optimizer.zero_grad()
                
            output = model(data)
            loss = criterion(output, target)
            
            if is_training:
                loss.backward()
                optimizer.step()
            
            total_loss += loss.item()
            _, predicted = output.max(1)
            total += target.size(0)
            correct += predicted.eq(target).sum().item()
    
    avg_loss = total_loss / len(loader)
    accuracy = 100. * correct / total
    return avg_loss, accuracy

def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                device, num_epochs=100, patience=7, checkpoint_path='best_model.pt'):
    """Train a model with early stopping and checkpointing."""
    early_stopping = EarlyStopping(patience=patience, path=checkpoint_path)
    history = defaultdict(list)
    best_acc = 0.0
    start_time = time()
    
    print("Training started...")
    for epoch in range(num_epochs):
        epoch_start = time()
        
        # Training phase
        train_loss, train_acc = train_epoch(
            model, train_loader, criterion, optimizer, device, is_training=True
        )
        
        # Validation phase
        val_loss, val_acc = train_epoch(
            model, val_loader, criterion, optimizer, device, is_training=False
        )

        scheduler.step(val_loss)
        
        # Save metrics
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        history['lr'].append(optimizer.param_groups[0]['lr'])
        
        # Print epoch results
        print(f"\nEpoch {epoch+1}/{num_epochs} - Time: {time() - epoch_start:.2f}s")
        print(f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.2f}%")
        print(f"Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.2f}%")
        print(f"Learning Rate: {optimizer.param_groups[0]['lr']:.6f}")
        print("-" * 60)
        
        # Early stopping check
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break
        
        # Save best model
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_loss': train_loss,
                'val_loss': val_loss,
                'train_acc': train_acc,
                'val_acc': val_acc,
            }, 'best_acc_model.pt')
    
    total_time = time() - start_time
    print(f"\nTraining completed in {total_time:.2f} seconds")
    print(f"Best validation accuracy: {best_acc:.2f}%")
    
    return history

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create model and training components
model, criterion, optimizer, scheduler = create_model(device)

test_loss, test_acc = train_epoch(
    model, test_loader, criterion, optimizer, device, is_training=False
)
print(f"Test Loss: {test_loss:.4f} - Test Acc: {test_acc:.2f}%")
# Out:
# /home/raphael/.cache/pypoetry/virtualenvs/data-science-practice-izly4xBC-py3.12/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 # Create model and training components
#       5 model, criterion, optimizer, scheduler = create_model(device)
#       7 test_loss, test_acc = train_epoch(
# ----> 8     model, test_loader, criterion, optimizer, device, is_training=False
#       9 )
#      10 print(f"Test Loss: {test_loss:.4f} - Test Acc: {test_acc:.2f}%")
#
# NameError: name 'test_loader' is not defined

# %%
# Train the model
history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    scheduler=scheduler,
    num_epochs=100,
    patience=7
)
# Out:
# Training started...
#
# Epoch 1/100 - Time: 7.11s
# Train Loss: 0.3787 - Train Acc: 88.57%
# Val Loss: 0.2235 - Val Acc: 93.24%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (inf --> 0.223503). Saving model ...
#
# Epoch 2/100 - Time: 7.95s
# Train Loss: 0.3137 - Train Acc: 90.72%
# Val Loss: 0.2487 - Val Acc: 92.79%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 3/100 - Time: 6.80s
# Train Loss: 0.3064 - Train Acc: 90.86%
# Val Loss: 0.2144 - Val Acc: 93.73%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.223503 --> 0.214403). Saving model ...
#
# Epoch 4/100 - Time: 7.36s
# Train Loss: 0.2930 - Train Acc: 91.12%
# Val Loss: 0.2159 - Val Acc: 93.43%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 5/100 - Time: 7.20s
# Train Loss: 0.2968 - Train Acc: 91.20%
# Val Loss: 0.2037 - Val Acc: 93.83%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.214403 --> 0.203675). Saving model ...
#
# Epoch 6/100 - Time: 8.50s
# Train Loss: 0.2897 - Train Acc: 91.26%
# Val Loss: 0.1871 - Val Acc: 94.07%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.203675 --> 0.187145). Saving model ...
#
# Epoch 7/100 - Time: 8.37s
# Train Loss: 0.2828 - Train Acc: 91.58%
# Val Loss: 0.1848 - Val Acc: 94.47%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.187145 --> 0.184798). Saving model ...
#
# Epoch 8/100 - Time: 10.16s
# Train Loss: 0.2798 - Train Acc: 91.59%
# Val Loss: 0.1898 - Val Acc: 94.21%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 9/100 - Time: 8.00s
# Train Loss: 0.2829 - Train Acc: 91.51%
# Val Loss: 0.1780 - Val Acc: 94.54%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.184798 --> 0.177986). Saving model ...
#
# Epoch 10/100 - Time: 9.48s
# Train Loss: 0.2836 - Train Acc: 91.67%
# Val Loss: 0.2122 - Val Acc: 93.80%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 11/100 - Time: 7.43s
# Train Loss: 0.2701 - Train Acc: 91.87%
# Val Loss: 0.1846 - Val Acc: 94.38%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 12/100 - Time: 7.32s
# Train Loss: 0.2814 - Train Acc: 91.65%
# Val Loss: 0.1908 - Val Acc: 94.56%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 13/100 - Time: 7.60s
# Train Loss: 0.2829 - Train Acc: 91.67%
# Val Loss: 0.1648 - Val Acc: 95.09%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# Validation loss decreased (0.177986 --> 0.164782). Saving model ...
#
# Epoch 14/100 - Time: 8.41s
# Train Loss: 0.2717 - Train Acc: 91.90%
# Val Loss: 0.1819 - Val Acc: 94.56%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 15/100 - Time: 7.24s
# Train Loss: 0.2800 - Train Acc: 91.71%
# Val Loss: 0.1863 - Val Acc: 94.52%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 16/100 - Time: 7.34s
# Train Loss: 0.2697 - Train Acc: 92.02%
# Val Loss: 0.1951 - Val Acc: 93.99%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 17/100 - Time: 7.76s
# Train Loss: 0.2772 - Train Acc: 91.92%
# Val Loss: 0.1795 - Val Acc: 94.72%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 4 out of 7
#
# Epoch 18/100 - Time: 7.52s
# Train Loss: 0.2759 - Train Acc: 91.79%
# Val Loss: 0.1811 - Val Acc: 94.70%
# Learning Rate: 0.010000
# ------------------------------------------------------------
# EarlyStopping counter: 5 out of 7
#
# Epoch 19/100 - Time: 9.72s
# Train Loss: 0.2782 - Train Acc: 91.64%
# Val Loss: 0.1766 - Val Acc: 94.66%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 6 out of 7
#
# Epoch 20/100 - Time: 9.86s
# Train Loss: 0.1843 - Train Acc: 94.43%
# Val Loss: 0.1155 - Val Acc: 96.50%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.164782 --> 0.115467). Saving model ...
#
# Epoch 21/100 - Time: 11.47s
# Train Loss: 0.1542 - Train Acc: 95.48%
# Val Loss: 0.1047 - Val Acc: 96.90%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.115467 --> 0.104651). Saving model ...
#
# Epoch 22/100 - Time: 10.86s
# Train Loss: 0.1370 - Train Acc: 95.87%
# Val Loss: 0.0960 - Val Acc: 97.08%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.104651 --> 0.096007). Saving model ...
#
# Epoch 23/100 - Time: 9.15s
# Train Loss: 0.1293 - Train Acc: 96.09%
# Val Loss: 0.0957 - Val Acc: 96.92%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.096007 --> 0.095675). Saving model ...
#
# Epoch 24/100 - Time: 9.36s
# Train Loss: 0.1238 - Train Acc: 96.17%
# Val Loss: 0.0941 - Val Acc: 97.10%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.095675 --> 0.094081). Saving model ...
#
# Epoch 25/100 - Time: 9.13s
# Train Loss: 0.1143 - Train Acc: 96.45%
# Val Loss: 0.0915 - Val Acc: 97.07%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.094081 --> 0.091452). Saving model ...
#
# Epoch 26/100 - Time: 8.37s
# Train Loss: 0.1100 - Train Acc: 96.61%
# Val Loss: 0.0865 - Val Acc: 97.28%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.091452 --> 0.086528). Saving model ...
#
# Epoch 27/100 - Time: 8.05s
# Train Loss: 0.1069 - Train Acc: 96.66%
# Val Loss: 0.0844 - Val Acc: 97.42%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.086528 --> 0.084431). Saving model ...
#
# Epoch 28/100 - Time: 8.53s
# Train Loss: 0.1033 - Train Acc: 96.80%
# Val Loss: 0.0831 - Val Acc: 97.39%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.084431 --> 0.083063). Saving model ...
#
# Epoch 29/100 - Time: 12.23s
# Train Loss: 0.1053 - Train Acc: 96.72%
# Val Loss: 0.0862 - Val Acc: 97.32%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 30/100 - Time: 8.37s
# Train Loss: 0.1007 - Train Acc: 96.88%
# Val Loss: 0.0837 - Val Acc: 97.39%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 31/100 - Time: 7.96s
# Train Loss: 0.0961 - Train Acc: 97.03%
# Val Loss: 0.0853 - Val Acc: 97.52%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 32/100 - Time: 9.38s
# Train Loss: 0.0934 - Train Acc: 96.99%
# Val Loss: 0.0812 - Val Acc: 97.52%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# Validation loss decreased (0.083063 --> 0.081193). Saving model ...
#
# Epoch 33/100 - Time: 9.20s
# Train Loss: 0.0948 - Train Acc: 97.03%
# Val Loss: 0.0895 - Val Acc: 97.34%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 34/100 - Time: 7.27s
# Train Loss: 0.0914 - Train Acc: 97.10%
# Val Loss: 0.0943 - Val Acc: 97.14%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 35/100 - Time: 7.27s
# Train Loss: 0.0890 - Train Acc: 97.19%
# Val Loss: 0.0864 - Val Acc: 97.49%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 36/100 - Time: 8.07s
# Train Loss: 0.0884 - Train Acc: 97.32%
# Val Loss: 0.0890 - Val Acc: 97.38%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 4 out of 7
#
# Epoch 37/100 - Time: 7.74s
# Train Loss: 0.0860 - Train Acc: 97.16%
# Val Loss: 0.0840 - Val Acc: 97.42%
# Learning Rate: 0.001000
# ------------------------------------------------------------
# EarlyStopping counter: 5 out of 7
#
# Epoch 38/100 - Time: 9.16s
# Train Loss: 0.0869 - Train Acc: 97.27%
# Val Loss: 0.0878 - Val Acc: 97.42%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 6 out of 7
#
# Epoch 39/100 - Time: 7.61s
# Train Loss: 0.0728 - Train Acc: 97.71%
# Val Loss: 0.0757 - Val Acc: 97.60%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.081193 --> 0.075749). Saving model ...
#
# Epoch 40/100 - Time: 8.62s
# Train Loss: 0.0637 - Train Acc: 97.97%
# Val Loss: 0.0714 - Val Acc: 97.80%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.075749 --> 0.071434). Saving model ...
#
# Epoch 41/100 - Time: 8.48s
# Train Loss: 0.0618 - Train Acc: 98.03%
# Val Loss: 0.0709 - Val Acc: 97.91%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.071434 --> 0.070942). Saving model ...
#
# Epoch 42/100 - Time: 8.82s
# Train Loss: 0.0554 - Train Acc: 98.21%
# Val Loss: 0.0705 - Val Acc: 97.81%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.070942 --> 0.070523). Saving model ...
#
# Epoch 43/100 - Time: 8.74s
# Train Loss: 0.0578 - Train Acc: 98.12%
# Val Loss: 0.0713 - Val Acc: 97.84%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 44/100 - Time: 7.84s
# Train Loss: 0.0538 - Train Acc: 98.29%
# Val Loss: 0.0698 - Val Acc: 97.88%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.070523 --> 0.069789). Saving model ...
#
# Epoch 45/100 - Time: 9.17s
# Train Loss: 0.0532 - Train Acc: 98.28%
# Val Loss: 0.0712 - Val Acc: 97.76%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 46/100 - Time: 7.87s
# Train Loss: 0.0513 - Train Acc: 98.30%
# Val Loss: 0.0731 - Val Acc: 97.82%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 47/100 - Time: 8.90s
# Train Loss: 0.0520 - Train Acc: 98.30%
# Val Loss: 0.0693 - Val Acc: 97.97%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.069789 --> 0.069343). Saving model ...
#
# Epoch 48/100 - Time: 9.50s
# Train Loss: 0.0478 - Train Acc: 98.45%
# Val Loss: 0.0682 - Val Acc: 97.89%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.069343 --> 0.068187). Saving model ...
#
# Epoch 49/100 - Time: 8.62s
# Train Loss: 0.0480 - Train Acc: 98.41%
# Val Loss: 0.0712 - Val Acc: 97.96%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 50/100 - Time: 7.85s
# Train Loss: 0.0474 - Train Acc: 98.41%
# Val Loss: 0.0694 - Val Acc: 97.94%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 51/100 - Time: 8.54s
# Train Loss: 0.0483 - Train Acc: 98.46%
# Val Loss: 0.0703 - Val Acc: 98.01%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 52/100 - Time: 9.88s
# Train Loss: 0.0459 - Train Acc: 98.49%
# Val Loss: 0.0690 - Val Acc: 98.01%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 4 out of 7
#
# Epoch 53/100 - Time: 8.32s
# Train Loss: 0.0433 - Train Acc: 98.61%
# Val Loss: 0.0695 - Val Acc: 98.04%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 5 out of 7
#
# Epoch 54/100 - Time: 9.97s
# Train Loss: 0.0452 - Train Acc: 98.48%
# Val Loss: 0.0670 - Val Acc: 98.03%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# Validation loss decreased (0.068187 --> 0.067020). Saving model ...
#
# Epoch 55/100 - Time: 8.42s
# Train Loss: 0.0438 - Train Acc: 98.57%
# Val Loss: 0.0693 - Val Acc: 97.99%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 1 out of 7
#
# Epoch 56/100 - Time: 8.00s
# Train Loss: 0.0439 - Train Acc: 98.60%
# Val Loss: 0.0712 - Val Acc: 97.93%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 2 out of 7
#
# Epoch 57/100 - Time: 7.79s
# Train Loss: 0.0448 - Train Acc: 98.50%
# Val Loss: 0.0705 - Val Acc: 97.93%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 3 out of 7
#
# Epoch 58/100 - Time: 8.46s
# Train Loss: 0.0428 - Train Acc: 98.56%
# Val Loss: 0.0700 - Val Acc: 98.04%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 4 out of 7
#
# Epoch 59/100 - Time: 8.11s
# Train Loss: 0.0415 - Train Acc: 98.66%
# Val Loss: 0.0744 - Val Acc: 97.88%
# Learning Rate: 0.000100
# ------------------------------------------------------------
# EarlyStopping counter: 5 out of 7
#
# Epoch 60/100 - Time: 7.75s
# Train Loss: 0.0409 - Train Acc: 98.70%
# Val Loss: 0.0739 - Val Acc: 97.83%
# Learning Rate: 0.000010
# ------------------------------------------------------------
# EarlyStopping counter: 6 out of 7
#
# Epoch 61/100 - Time: 8.34s
# Train Loss: 0.0403 - Train Acc: 98.69%
# Val Loss: 0.0713 - Val Acc: 97.89%
# Learning Rate: 0.000010
# ------------------------------------------------------------
# EarlyStopping counter: 7 out of 7
# Early stopping triggered
#
# Training completed in 519.12 seconds
# Best validation accuracy: 98.04%

# %%
def plot_training_history(history):
    """
    Plot training history
    
    Parameters:
    -----------
    history : dict
        Training history containing metrics
    """
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Plot loss
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Val Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.legend()
    ax1.grid(True)
    
    # Plot accuracy
    ax2.plot(history['train_acc'], label='Train Acc')
    ax2.plot(history['val_acc'], label='Val Acc')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.set_title('Training and Validation Accuracy')
    ax2.legend()
    ax2.grid(True)
    
    # Plot learning rate
    ax3.plot(history['lr'])
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Learning Rate')
    ax3.set_title('Learning Rate over Time')
    ax3.set_yscale('log')
    ax3.grid(True)
    
    # Plot loss vs accuracy
    ax4.scatter(history['train_loss'], history['train_acc'], label='Train')
    ax4.scatter(history['val_loss'], history['val_acc'], label='Val')
    ax4.set_xlabel('Loss')
    ax4.set_ylabel('Accuracy (%)')
    ax4.set_title('Loss vs Accuracy')
    ax4.legend()
    ax4.grid(True)
    
    plt.tight_layout()
    return fig

# %%
# Plot training history
plot_training_history(history)
plt.show()

# %% [markdown]
# ### Eval on test

# %%
test_loss, test_acc = train_epoch(
    model, test_loader, criterion, optimizer, device, is_training=False
)
print(f"Test Loss: {test_loss:.4f} - Test Acc: {test_acc:.2f}%")
# Out:
# Test Loss: 0.0782 - Test Acc: 98.06%
