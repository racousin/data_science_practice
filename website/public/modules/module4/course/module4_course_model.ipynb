# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
StoreA_data.csv
StoreB_data.csv
StoreC_data.xlsx
StoreD_data.json

StoreE_data.csv

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Files sources

# %%
import requests

# URLs of the files
train_data_url_StoreA = 'https://www.raphaelcousin.com/modules/module3/course/StoreA_data.csv'
train_data_url_StoreA = 'https://www.raphaelcousin.com/modules/module3/course/StoreB_data.csv'
train_data_url_StoreA = 'https://www.raphaelcousin.com/modules/module3/course/StoreC_data.xlsx'
train_data_url_StoreA = 'https://www.raphaelcousin.com/modules/module3/course/StoreD_data.json'

test_data_url = 'https://www.raphaelcousin.com/modules/module3/course/StoreE_data.csv'

# Function to download a file
def download_file(url, file_name):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(file_name, 'wb') as file:
        file.write(response.content)
    print(f'Downloaded {file_name} from {url}')

# Downloading the files
download_file(train_data_url_StoreA, 'StoreA_data.csv')
download_file(train_data_url_StoreB, 'StoreB_data.csv')
download_file(train_data_url_StoreC, 'StoreC_data.xlsx')
download_file(train_data_url_StoreD, 'StoreD_data.json')

download_file(test_data_url, 'StoreE_data.csv')

# %% [markdown]
# #### StoreA

# %%
# read
df_StoreA =  pd.read_csv("StoreA_data.csv", sep=",", index_col='product_id')
df_StoreA
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0019       StoreA    8.71   12.81  58.68                   190
# P0024       StoreA    3.42   41.28  38.92                   115
# P0025       StoreA    8.05   24.54  92.99                   337
# P0034       StoreA    4.58   32.82   7.77                    85
# P0039       StoreA    5.03   82.12  42.79                   266
# ...            ...     ...     ...    ...                   ...
# P0956       StoreA    2.23   69.04  91.37                   168
# P0960       StoreA    8.04   32.60  23.11                   163
# P0967       StoreA     NaN   64.94  55.49                    84
# P0997       StoreA    5.17   59.11  61.51                   316
# P0998       StoreA    6.83   29.66  75.19                   265
#
#             days_in_stock  price  number_sold last_updated
# product_id
# P0019                 651  17.23          214   2023-01-19
# ...

# %% [markdown]
# #### StoreB

# %%
# read
df_StoreB =  pd.read_csv("StoreB_data.csv", sep=";", header=1, index_col='PRODUCT_ID')
df_StoreB
# Out:
#              STORE  WEIGHT  LENGTH  WIDTH  DAYS_SINCE_LAST_SALE  \
# PRODUCT_ID
# P0006       StoreB    1.61   75.06  91.25                   301
# P0014       StoreB    1.22   14.35  73.24                   272
# P0016       StoreB    8.41   77.62  65.86                   255
# P0021       StoreB    5.95   33.07  52.40                    24
# P0028       StoreB    4.04   78.59  26.10                   136
# ...            ...     ...     ...    ...                   ...
# P0984       StoreB    8.42   24.87  90.35                   276
# P0990       StoreB    8.96   27.99  14.92                   342
# P0991       StoreB    6.40   96.26  59.80                   104
# P0994       StoreB    5.23   99.51  98.15                    32
# P0996       StoreB    7.40   98.21  11.39                   230
#
#             DAYS_IN_STOCK  PRICE  NUMBER_SOLD LAST_UPDATED  Unnamed: 10
# PRODUCT_ID
# P0006               783.0   8.26          220   2023-01-06          NaN
# ...

# %%
# format
df_StoreB.drop('Unnamed: 10', axis=1, inplace=True)
df_StoreB.columns = [col.lower() for col in df_StoreB.columns]
df_StoreB.rename_axis(df_StoreB.index.name.lower(), inplace=True)
df_StoreB
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0006       StoreB    1.61   75.06  91.25                   301
# P0014       StoreB    1.22   14.35  73.24                   272
# P0016       StoreB    8.41   77.62  65.86                   255
# P0021       StoreB    5.95   33.07  52.40                    24
# P0028       StoreB    4.04   78.59  26.10                   136
# ...            ...     ...     ...    ...                   ...
# P0984       StoreB    8.42   24.87  90.35                   276
# P0990       StoreB    8.96   27.99  14.92                   342
# P0991       StoreB    6.40   96.26  59.80                   104
# P0994       StoreB    5.23   99.51  98.15                    32
# P0996       StoreB    7.40   98.21  11.39                   230
#
#             days_in_stock  price  number_sold last_updated
# product_id
# P0006               783.0   8.26          220   2023-01-06
# ...

# %% [markdown]
# #### StoreC

# %%
# read
df_StoreCs =  pd.read_excel("StoreC_data.xlsx", sheet_name=None)
df_StoreCs
# Out:
# {'Sheet1':     product_id  number_sold
#  0        P0003           28
#  1        P0007           26
#  2        P0008           34
#  3        P0009           17
#  4        P0012            9
#  ..         ...          ...
#  185      P0985           46
#  186      P0986           25
#  187      P0989           12
#  188      P0992            3
#  189      P1000           54
#
#  [190 rows x 2 columns],
#  'Sheet2':     product id   store  weight  length  width  days_since_last_sale  \
#  0        P0003  StoreC    7.00   11.77  98.21                   120
#  1        P0007  StoreC    5.81   38.56  94.65                   254
#  2        P0008  StoreC    6.11   33.17  96.21                   121
#  3        P0009  StoreC    4.30   38.22  54.54                    30
#  4        P0012  StoreC    9.26   22.59  20.36                   105
#  ..         ...     ...     ...     ...    ...                   ...
#  185      P0985  StoreC    0.48    9.75  42.95                    64
# ...

# %%
# format
df_StoreC = pd.merge(df_StoreCs['Sheet1'], df_StoreCs['Sheet2'], left_on = 'product_id' , right_on = 'product id')
df_StoreC = df_StoreC[['product_id', 'store', 'weight', 'length', 'width', 'days_since_last_sale', 'days_in_stock',	'price']]
df_StoreC.set_index('product_id', inplace=True)
df_StoreC
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0003       StoreC    7.00   11.77  98.21                   120
# P0007       StoreC    5.81   38.56  94.65                   254
# P0008       StoreC    6.11   33.17  96.21                   121
# P0009       StoreC    4.30   38.22  54.54                    30
# P0012       StoreC    9.26   22.59  20.36                   105
# ...            ...     ...     ...    ...                   ...
# P0985       StoreC    0.48    9.75  42.95                    64
# P0986       StoreC    9.03   85.15  36.05                   270
# P0989       StoreC    6.63   86.11  81.09                   137
# P0992       StoreC    6.18   23.71  49.08                    33
# P1000       StoreC    0.94   61.39  67.58                   339
#
#             days_in_stock  price
# product_id
# P0003               513.0  17.85
# P0007               753.0  11.94
# P0008               540.0   7.24
# P0009               735.0   8.37
# ...

# %% [markdown]
# #### StoreD

# %%
# read
df_StoreD = pd.read_json('StoreD_data.json', orient='records')
df_StoreD
# Out:
#     product_id   store  weight  length  width  days_since_last_sale  \
# 0        P0001  StoreD    9.33   73.05  11.94                   236
# 1        P0011  StoreD    9.35   67.83  76.94                   284
# 2        P0015  StoreD    9.85   67.73  28.50                   231
# 3        P0017  StoreD    1.33   30.18  68.33                    23
# 4        P0020  StoreD    5.24   96.95  78.30                   346
# ..         ...     ...     ...     ...    ...                   ...
# 201      P0982  StoreD    4.43   20.75  58.83                   256
# 202      P0983  StoreD    2.62   47.33  67.42                   294
# 203      P0988  StoreD    6.41   80.35  83.52                   316
# 204      P0993  StoreD    0.76   95.39  16.28                   109
# 205      P0999  StoreD    0.51   46.51   8.08                   181
#
#      days_in_stock  price  number_sold   last_updated
# 0             65.0  12.00           40  1672531200000
# ...

# %%
# format
df_StoreD.set_index('product_id', inplace=True)
df_StoreD
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0001       StoreD    9.33   73.05  11.94                   236
# P0011       StoreD    9.35   67.83  76.94                   284
# P0015       StoreD    9.85   67.73  28.50                   231
# P0017       StoreD    1.33   30.18  68.33                    23
# P0020       StoreD    5.24   96.95  78.30                   346
# ...            ...     ...     ...    ...                   ...
# P0982       StoreD    4.43   20.75  58.83                   256
# P0983       StoreD    2.62   47.33  67.42                   294
# P0988       StoreD    6.41   80.35  83.52                   316
# P0993       StoreD    0.76   95.39  16.28                   109
# P0999       StoreD    0.51   46.51   8.08                   181
#
#             days_in_stock  price  number_sold   last_updated
# product_id
# P0001                65.0  12.00           40  1672531200000
# ...

# %% [markdown]
# #### Aggregate

# %%
data = pd.concat([df_StoreA, df_StoreB, df_StoreC, df_StoreD], axis=0)
data
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0019       StoreA    8.71   12.81  58.68                   190
# P0024       StoreA    3.42   41.28  38.92                   115
# P0025       StoreA    8.05   24.54  92.99                   337
# P0034       StoreA    4.58   32.82   7.77                    85
# P0039       StoreA    5.03   82.12  42.79                   266
# ...            ...     ...     ...    ...                   ...
# P0982       StoreD    4.43   20.75  58.83                   256
# P0983       StoreD    2.62   47.33  67.42                   294
# P0988       StoreD    6.41   80.35  83.52                   316
# P0993       StoreD    0.76   95.39  16.28                   109
# P0999       StoreD    0.51   46.51   8.08                   181
#
#             days_in_stock  price  number_sold   last_updated
# product_id
# P0019               651.0  17.23        214.0     2023-01-19
# ...

# %% [markdown]
# #### Simple baseline

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import numpy as np

def get_simple_baseline(data, fillna_value=-1, drop_cols=None, k_fold=5, scaler='standard', model='linear', metric='mae', target_col=None):
    data = data.copy()
    # Handle missing values
    data.fillna(fillna_value, inplace=True)
    
    # Drop unwanted columns
    if drop_cols:
        data.drop(drop_cols, axis=1, inplace=True)

    # Split data into features (X) and target (y)
    y = data[target_col]
    X = data.drop(target_col, axis=1)

    # Feature scaling
    if scaler == 'standard':
        scaler = StandardScaler()
    elif scaler == 'minmax':
        scaler = MinMaxScaler()
    else:
        scaler = None
    
    if scaler:
        X = scaler.fit_transform(X)

    # Initialize the model
    if model == 'linear':
        model = LinearRegression()
    elif model == 'logistic':
        model = LogisticRegression()
    elif model == 'random_forest':
        model = RandomForestClassifier()
    else:
        raise ValueError("Unsupported model type")

    # Initialize cross-validation
    kf = KFold(n_splits=k_fold, shuffle=True, random_state=42)
    scores = []

    # Train and evaluate using k-fold cross-validation
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Train the model
        model.fit(X_train, y_train)
        
        # Make predictions
        y_pred = model.predict(X_test)
        
        # Evaluate using the specified metric
        if metric == 'mae':
            score = mean_absolute_error(y_test, y_pred)
        elif metric == 'accuracy':
            score = accuracy_score(y_test, np.round(y_pred))
        else:
            raise ValueError("Unsupported metric")

        scores.append(score)
    
    # Return the average score
    return np.mean(scores)

# %%
get_simple_baseline(data, fillna_value=-1, drop_cols=['store', 'last_updated'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='number_sold')
# Out:
# 64.04887330680228

# %% [markdown]
# ### API sources

# %%
def get_api(endpoint_url):
    try:
        # Make the GET request to the mock API
        response = requests.get(endpoint_url)

        if response.status_code == 200:
            data = response.json()
            print(data["message"])
            return data['data']
        else:
            print(f"Failed to retrieve volume data. Status code: {response.status_code}")
    
    except Exception as e:
        print(f"An error occurred: {e}")
password = get_api("http://localhost:3000/api/course/auth")["password"]
volumes = get_api(f"http://localhost:3000/api/course/{password}/volumes")
# Out:
# Authentication successful
# Volume data retrieved successfully

# %%
df_volumes = pd.DataFrame.from_dict(volumes, orient='index', columns=['volume'])

# %%
df_volumes
# Out:
#               volume
# P0001   48469.098690
# P0002   11252.963820
# P0003   24725.379063
# P0004    8361.648240
# P0005  255200.667150
# ...              ...
# P0996  106905.739283
# P0997   38976.377392
# P0998   74218.906112
# P0999   12521.682656
# P1000  147031.210928
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### Aggregate

# %%
data = pd.merge(data, df_volumes, left_index=True, right_index=True, how='left')
data
# Out:
#              store  weight  length  width  days_since_last_sale  \
# product_id
# P0019       StoreA    8.71   12.81  58.68                   190
# P0024       StoreA    3.42   41.28  38.92                   115
# P0025       StoreA    8.05   24.54  92.99                   337
# P0034       StoreA    4.58   32.82   7.77                    85
# P0039       StoreA    5.03   82.12  42.79                   266
# ...            ...     ...     ...    ...                   ...
# P0982       StoreD    4.43   20.75  58.83                   256
# P0983       StoreD    2.62   47.33  67.42                   294
# P0988       StoreD    6.41   80.35  83.52                   316
# P0993       StoreD    0.76   95.39  16.28                   109
# P0999       StoreD    0.51   46.51   8.08                   181
#
#             days_in_stock  price  number_sold   last_updated         volume
# product_id
# P0019               651.0  17.23        214.0     2023-01-19   21814.067016
# ...

# %%
get_simple_baseline(data, fillna_value=-1, drop_cols=['store', 'last_updated'], k_fold=5, scaler='standard', model='linear', metric='mae', target_col='number_sold')
# Out:
# 63.485194698627105

# %% [markdown]
# ### Scrapping sources

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Fetch the HTML content from the local server
url = 'http://localhost:3000/module4/scrapable-data'
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Initialize lists to store scraped data
    course_data = []
    exercise_data = []

    # Find both tables
    tables = soup.find_all('table')

    # Scrape the first table (Course Data)
    course_table = tables[0]
    for row in course_table.find('tbody').find_all('tr'):
        cols = row.find_all('td')
        course_data.append({
            'Product ID': cols[0].text,
            'Rating': float(cols[1].text),
            'Number of Reviews': int(cols[2].text),
            'Random Feature': cols[3].text
        })

    # Scrape the second table (Exercise Data)
    exercise_table = tables[1]
    for row in exercise_table.find('tbody').find_all('tr'):
        cols = row.find_all('td')
        exercise_data.append({
            'Product ID': cols[0].text,
            'Rating': float(cols[1].text),
            'Number of Reviews': int(cols[2].text),
            'Random Feature': cols[3].text
        })

    # Convert the lists to pandas DataFrames
    df_course = pd.DataFrame(course_data)
    df_exercise = pd.DataFrame(exercise_data)

    # Display the DataFrames
    print("Course Data:")
    print(df_course.head())

    print("\nExercise Data:")
    print(df_exercise.head())

else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[115], line 22
#      19 tables = soup.find_all('table')
#      21 # Scrape the first table (Course Data)
# ---> 22 course_table = tables[0]
#      23 for row in course_table.find('tbody').find_all('tr'):
#      24     cols = row.find_all('td')
#
# IndexError: list index out of range

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="icon"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#000000" name="theme-color"/>
# <meta content="Web site created using create-react-app" name="description"/>
# <link href="/logo192.png" rel="apple-touch-icon"/>
# <!--
#       manifest.json provides metadata used when your web app is installed on a
#       user's mobile device or desktop. See https://developers.google.com/web/fundamentals/web-app-manifest/
#     -->
# <link href="/manifest.json" rel="manifest"/>
# <!--
#       Notice the use of  in the tags above.
#       It will be replaced with the URL of the `public` folder during the build.
#       Only files inside the `public` folder can be referenced from the HTML.
#
#       Unlike "/favicon.ico" or "favicon.ico", "/favicon.ico" will
#       work correctly both with client-side routing and a non-root public URL.
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'store', 'weight', 'length', 'width', 'height', 'rating',
#        'num_reviews', 'days_since_last_sale', 'volume', 'days_in_stock',
#        'price', 'number_sold', 'last_updated'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Correlation matrix
print("\nCorrelation matrix:")
corr_matrix = df.iloc[:,2:].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()
# Out:
# Correlation matrix:

# %%
dfa = df[df['store'] == 'StoreA']
dfe = df[df['store'] == 'StoreE']

# %%
dfa
# Out:
#     product_id   store  weight  length  width  height  rating  num_reviews  \
# 18       P0019  StoreA    8.71   12.81  58.68   29.02       5          675
# 23       P0024  StoreA    3.42   41.28  38.92   50.35       2          837
# 24       P0025  StoreA    8.05   24.54  92.99   38.33       4          688
# 33       P0034  StoreA    4.58   32.82   7.77   26.02       5          254
# 38       P0039  StoreA    5.03   82.12  42.79   48.62       3          765
# ..         ...     ...     ...     ...    ...     ...     ...          ...
# 955      P0956  StoreA    2.23   69.04  91.37   47.20       2          217
# 959      P0960  StoreA    8.04   32.60  23.11   87.27       2          382
# 966      P0967  StoreA    1.07   64.94  55.49   76.68       2          423
# 996      P0997  StoreA    5.17   59.11  61.51   10.72       3          197
# 997      P0998  StoreA    6.83   29.66  75.19   33.28       4          812
#
# ...

# %%
dfe
# Out:
#     product_id   store  weight  length  width  height  rating  num_reviews  \
# 1        P0002  StoreE    5.69   11.85  64.12   14.81       3          209
# 3        P0004  StoreE    9.23    6.15  23.06   58.96       1          491
# 4        P0005  StoreE    7.10   95.87  80.30   33.15       4          508
# 9        P0010  StoreE    7.39   78.59  97.84   97.12       1          257
# 12       P0013  StoreE    4.56   21.54  50.31    9.78       5          229
# ..         ...     ...     ...     ...    ...     ...     ...          ...
# 972      P0973  StoreE    3.82   52.56  20.62   72.11       3          938
# 973      P0974  StoreE    4.01   69.56  16.08   37.83       4          227
# 976      P0977  StoreE    8.93   81.66  37.68   27.30       4          808
# 986      P0987  StoreE    4.67   98.21   6.03   57.78       4          828
# 994      P0995  StoreE    1.59   72.61  25.40   15.15       1          768
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error

# %%
lr = LinearRegression()

# %%
dfe = df[df['store'] == 'StoreE']

for st in ['A', 'B', 'C', 'D']:
    print()
    for st2 in ['A', 'B', 'C', 'D']:
        if st == st2:
            continue
        df1 = df[df['store'] == f'Store{st}']
        df2 = df[df['store'] == f'Store{st2}']
        df_train = pd.concat([df1, df2])
        lr.fit(df_train.iloc[:, 2:-2], df_train.iloc[:, -2])
        pred = lr.predict(df_train.iloc[:, 2:-2])
        print(f"train on {st} x {st2}: {mean_absolute_error(pred, df_train.iloc[:, -2] )}")
        pred = lr.predict(dfe.iloc[:, 2:-2])
        print(f"test on E: {mean_absolute_error(pred, dfe.iloc[:, -2] )}")


train = df[df['store'] != 'StoreE']
lr.fit(train.iloc[:, 2:-2], train.iloc[:, -2])

print()

pred = lr.predict(train.iloc[:, 2:-2])
print(f"train all store: {mean_absolute_error(pred, train.iloc[:, -2] )}")

pred = lr.predict(dfe.iloc[:, 2:-2])
print(f"final test on E: {mean_absolute_error(pred, dfe.iloc[:, -2] )}")
# Out:
# train on A x B: 22.719436360033054
# test on E: 59.90586283080063
# train on A x C: 69.06822374364761
# test on E: 12.584165286205995
# train on A x D: 61.10935613829524
# test on E: 17.774221750435938
#
# train on B x A: 22.719436360033065
# test on E: 59.9058628308007
# train on B x C: 48.50668448262841
# test on E: 15.569604549972196
# train on B x D: 40.98586209969353
# test on E: 8.004727061448614
#
# train on C x A: 69.06822374364835
# test on E: 12.584165286204735
# train on C x B: 48.50668448262831
# test on E: 15.569604549972313
# train on C x D: 14.072259618177462
# test on E: 58.39258894184352
#
# train on D x A: 61.109356138295354
# test on E: 17.774221750436
# train on D x B: 40.98586209969354
# test on E: 8.004727061448587
# train on D x C: 14.072259618177457
# test on E: 58.39258894184349
#
# train all store: 55.988962637394195
# final test on E: 3.8798861559155617

# %%
import json

# %%
# Create a dictionary with product_id as key and volume as value
product_data = df.set_index('product_id')['volume'].to_dict()
scrapable_data = df[['product_id', 'rating', 'num_reviews']].to_dict('records')
# Create the JavaScript code
js_code = f"""
// api-mock-data.js

// Mock product data
const mockProductData = {json.dumps(product_data, indent=2)};

// Fake API call function
export const fakeApiCall = (id, login, password, version) => {{
  return new Promise((resolve, reject) => {{
    setTimeout(() => {{
      // Simulate authentication
      if (login !== 'admin' || password !== 'password123') {{
        reject({{
          status: 401,
          message: 'Unauthorized: Invalid login or password.',
        }});
      }} else {{
        // Check if the product exists
        if (mockProductData.hasOwnProperty(id)) {{
          let responseData = {{
            id: id,
            volume: mockProductData[id],
            version: version,
            description: `This data is for the ${{version}} version.`,
          }};
          
          // Add version-specific data
          if (version === 'course') {{
            responseData.course_specific = Math.floor(Math.random() * 100);
          }} else if (version === 'exercise') {{
            responseData.exercise_specific = Math.floor(Math.random() * 50);
          }} else {{
            reject({{
              status: 400,
              message: 'Bad Request: Invalid version parameter.',
            }});
            return;
          }}
          
          resolve(responseData);
        }} else {{
          reject({{
            status: 404,
            message: 'Not Found: Product ID does not exist.',
          }});
        }}
      }}
    }}, 500); // Simulating a delay
  }});
}};
export const scrapableData = {json.dumps(scrapable_data, indent=2)};
"""

# Write the JavaScript code to a file
with open('api-mock-data.js', 'w') as js_file:
    js_file.write(js_code)

print("JavaScript file 'api-mock-data.js' has been generated.")
# Out:
# JavaScript file 'api-mock-data.js' has been generated.

# %%
export const scrapableData = {json.dumps(scrapable_data, indent=2)};

# %%
df.columns
# Out:
# Index(['product_id', 'store', 'weight', 'length', 'width', 'height', 'rating',
#        'num_reviews', 'days_since_last_sale', 'volume', 'days_in_stock',
#        'price', 'number_sold', 'last_updated'],
#       dtype='object')

# %%
df = df[['product_id', 'store', 'weight', 'length', 'width', 'days_since_last_sale', 'days_in_stock',
       'price', 'number_sold', 'last_updated']]

# %%
df
# Out:
#     product_id   store  weight  length  width  days_since_last_sale  \
# 0        P0001  StoreD    9.33   73.05  11.94                   236
# 1        P0002  StoreE    5.69   11.85  64.12                    25
# 2        P0003  StoreC    7.00   11.77  98.21                   120
# 3        P0004  StoreE    9.23    6.15  23.06                   181
# 4        P0005  StoreE    7.10   95.87  80.30                   198
# ..         ...     ...     ...     ...    ...                   ...
# 995      P0996  StoreB    7.40   98.21  11.39                   230
# 996      P0997  StoreA    5.17   59.11  61.51                   316
# 997      P0998  StoreA    6.83   29.66  75.19                   265
# 998      P0999  StoreD    0.51   46.51   8.08                   181
# 999      P1000  StoreC    0.94   61.39  67.58                   339
#
#      days_in_stock  price  number_sold last_updated
# 0               65  12.00           40   2023-01-01
# ...

# %%
# Split the data by store
stores = ['StoreA', 'StoreB', 'StoreC', 'StoreD', 'StoreE']
store_dfs = {store: df[df['store'] == store] for store in stores}

# %%
def add_null(df, n = 3, columns = ['weight', 'length', 'width', 'days_since_last_sale', 'days_in_stock', 'price']):
    # Randomly select one column
    selected_column = np.random.choice(columns)
    
    # Randomly select 'n' indices to set to NaN
    indices = np.random.choice(df.index, size=n, replace=False)
    
    # Set the selected indices in the chosen column to NaN
    df.loc[indices, selected_column] = np.nan

    return df

# %%
# 'StoreA'
store = 'StoreA'

store_dfs[store] = add_null(store_dfs[store])

store_dfs[store].to_csv(f'{store}_data.csv', index=False)

# %%
# 'StoreB'
store = 'StoreB'

store_dfs[store] = add_null(store_dfs[store])

# Write an empty line and then the data to CSV
with open(f'{store}_data.csv', 'w', newline='') as f:
    f.write(f'{";"*(len(store_dfs[store].columns) -1)}\n')  # Write an empty line
    store_dfs[store].to_csv(f, index=False, sep=';')

# %%
store_dfs[store].columns
# Out:
# Index(['product_id', 'store', 'weight', 'length', 'width',
#        'days_since_last_sale', 'days_in_stock', 'price', 'number_sold',
#        'last_updated'],
#       dtype='object')

# %%
# 'StoreC'
store = 'StoreC'

store_dfs[store] = add_null(store_dfs[store])

# Define the columns for each sheet
first_sheet_columns = ['product_id', 'number_sold']
second_sheet_columns = ['product_id', 'store', 'weight', 'length', 'width',
                        'days_since_last_sale', 'days_in_stock', 'price']

# Split the DataFrame
first_sheet_df = store_dfs[store][first_sheet_columns]
second_sheet_df = store_dfs[store][second_sheet_columns]

# Write to Excel in two sheets
with pd.ExcelWriter(f'{store}_data.xlsx', engine='openpyxl') as writer:
    first_sheet_df.to_excel(writer, sheet_name='Sheet1', index=False)
    second_sheet_df.to_excel(writer, sheet_name='Sheet2', index=False)

print(f"{store}_data.xlsx has been created with two sheets.")
# Out:
# StoreC_data.xlsx has been created with two sheets.

# %%
# 'StoreD'
store = 'StoreD'

store_dfs[store] = add_null(store_dfs[store])

store_dfs[store].to_json(f'{store}_data.json', orient='records')

# %%
# 'StoreE'
store = 'StoreE'

y = store_dfs[store][['product_id', 'number_sold']]
x = store_dfs[store].drop('number_sold', axis=1)

x.to_csv(f'{store}_data.csv', index=False)

y.to_csv(f'module4_course_test_target.csv', index=False)
